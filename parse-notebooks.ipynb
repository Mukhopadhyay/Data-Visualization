# %%
import json

# %%
with open('visualizations/Piechart/Piecharts.ipynb', 'r') as fp:
    notebook = json.load(fp)

# %%
notebook
# Out:
# {'cells': [{'cell_type': 'markdown',
#    'id': '412c67d8',
#    'metadata': {},
#    'source': ['# Piechart']},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'id': '8af43de4',
#    'metadata': {'ExecuteTime': {'end_time': '2022-05-19T15:29:52.210379Z',
#      'start_time': '2022-05-19T15:29:52.167648Z'}},
#    'outputs': [],
#    'source': ['import sys\n',
#     "sys.path.append('../../utils')\n",
#     '\n',
#     'import utils']},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'id': 'a18caaa9',
#    'metadata': {'ExecuteTime': {'end_time': '2022-05-19T15:29:52.447523Z',
#      'start_time': '2022-05-19T15:29:52.438499Z'}},
#    'outputs': [{'data': {'text/html': ['        <script type="text/javascript">\n',
#        "        window.PlotlyConfig = {MathJaxConfig: 'local'};\n",
#        '        if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}\n',
# ...

# %%
import base64

# %%
with open('test.png', 'wb') as f:
    f.write(
        base64.b64decode(
            notebook['cells'][5]['outputs'][0]['data']['image/png']
        )
    )
